# %%
# !pip install keras-applications
# Out:
# Collecting keras-applications
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.9.1 in /Users/malikchettih/.pyenv/versions/3.9.21/lib/python3.9/site-packages (from keras-applications) (1.26.4)
# Requirement already satisfied: h5py in /Users/malikchettih/.pyenv/versions/3.9.21/lib/python3.9/site-packages (from keras-applications) (3.13.0)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
# Installing collected packages: keras-applications
# Successfully installed keras-applications-1.0.8

# %%
from keras_mixnets import MixNetSmall  # Medium and Large can also be used

model = MixNetSmall((224, 224, 3), include_top=True)
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from keras_mixnets import MixNetSmall  # Medium and Large can also be used
#       3 model = MixNetSmall((224, 224, 3), include_top=True)
#       4 model.summary()
#
# File ~/Projects/Emiasd-Projects/Emiasd-DeepLearning/03.Models/MixNet/keras_mixnets/__init__.py:1
# ----> 1 from keras_mixnets.mixnets import *
#       2 from keras_mixnets.config import BlockArgs
#       4 __version__ = '0.1.0'
#
# File ~/Projects/Emiasd-Projects/Emiasd-DeepLearning/03.Models/MixNet/keras_mixnets/mixnets.py:33
#      31 from keras_mixnets.config import BlockArgs
#      32 from keras_mixnets.config import get_mixnet_small, get_mixnet_medium, get_mixnet_large
# ---> 33 from keras_mixnets.custom_objects import DropConnect
#      34 from keras_mixnets.custom_objects import MixNetConvInitializer
#      35 from keras_mixnets.custom_objects import MixNetDenseInitializer
#
# File ~/Projects/Emiasd-Projects/Emiasd-DeepLearning/03.Models/MixNet/keras_mixnets/custom_objects.py:7
#       5 from keras import layers
#       6 from keras import models
# ----> 7 from keras.backend import conv_utils
#       8 from keras.utils.generic_utils import get_custom_objects
#      11 # Obtained from https://github.com/tensorflow/tpu/blob/master/models/official/efficientnet/efficientnet_model.py
#
# ImportError: cannot import name 'conv_utils' from 'keras.backend' (/Users/malikchettih/.pyenv/versions/3.9.21/lib/python3.9/site-packages/keras/backend/__init__.py)
