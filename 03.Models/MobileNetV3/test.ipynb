# %%
from model.mobilenet_v3_small import MobileNetV3_Small

shape = (19, 19, 3)
n_class = 361
alpha = 1
model = MobileNetV3_Small(shape, n_class, alpha).build()
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_6 (InputLayer)        [(None, 19, 19, 3)]          0         []
#
#  conv2d_107 (Conv2D)         (None, 10, 10, 16)           448       ['input_6[0][0]']
#
#  batch_normalization_143 (B  (None, 10, 10, 16)           64        ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_103 (Activation  (None, 10, 10, 16)           0         ['batch_normalization_143[0][0
#  )                                                                  ]']
#
#  conv2d_108 (Conv2D)         (None, 10, 10, 16)           272       ['activation_103[0][0]']
#
#  batch_normalization_144 (B  (None, 10, 10, 16)           64        ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_104 (Activation  (None, 10, 10, 16)           0         ['batch_normalization_144[0][0
# ...
