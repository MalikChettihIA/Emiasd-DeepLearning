# %%
# !pip install pydot

# %%
from mobilenet_v2 import MobileNetv2


model = MobileNetv2((19,19,31), 361, 0.1)
print(model.summary())
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_14 (InputLayer)       [(None, 19, 19, 31)]         0         []
#
#  conv2d_413 (Conv2D)         (None, 10, 10, 8)            2240      ['input_14[0][0]']
#
#  batch_normalization_589 (B  (None, 10, 10, 8)            32        ['conv2d_413[0][0]']
#  atchNormalization)
#
#  activation_402 (Activation  (None, 10, 10, 8)            0         ['batch_normalization_589[0][0
#  )                                                                  ]']
#
#  conv2d_414 (Conv2D)         (None, 10, 10, 8)            72        ['activation_402[0][0]']
#
#  batch_normalization_590 (B  (None, 10, 10, 8)            32        ['conv2d_414[0][0]']
#  atchNormalization)
#
#  activation_403 (Activation  (None, 10, 10, 8)            0         ['batch_normalization_590[0][0
# ...
