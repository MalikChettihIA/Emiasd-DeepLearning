# %%
# !pip install tqdm

# %%
from alphazero_lite_go import get_model, AlphaZeroLite, GoGame
from tensorflow import keras

# Charger l’ancien modèle
model = keras.models.load_model("mchettih.h5", compile=True)

# Réentraînement par self-play
az = AlphaZeroLite(model, GoGame, num_simulations=50)
az.train_from_selfplay(n_games=5, batch_size=64, epochs=3)

# Sauvegarder la nouvelle version
model.save("mchettih_v2.h5")
# Out:
# 2025-04-05 08:19:08.594775: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M4 Pro
# 2025-04-05 08:19:08.594796: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 48.00 GB
# 2025-04-05 08:19:08.594800: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 18.00 GB
# 2025-04-05 08:19:08.594829: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-04-05 08:19:08.594849: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# ...
