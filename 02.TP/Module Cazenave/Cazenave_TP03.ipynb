# %% [markdown]
# # Residual Networks

# %%
import numpy as np
import tensorflow as tf

from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from keras.layers import Conv2D, Flatten, Reshape
from keras import layers


from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

inputs = keras.Input(shape=(784,), name='img')
x = Reshape((28, 28, 1))(inputs)  # Reshape en 28x28x1
x = Conv2D(32, kernel_size=(3, 3), activation='relu')(x)
x = Conv2D(64, (3, 3), activation='relu')(x)
x = Flatten()(x)
x = layers.Dense(128, activation='relu')(x)
outputs = layers.Dense(10, activation='softmax')(x)
model = keras.Model(inputs=inputs, outputs=outputs,cname='mnist_model')

model.compile(loss='sparse_categorical_crossentropy', optimizer=keras.optimizers.RMSprop(), metrics=['accuracy'])
model.fit(train_images, train_labels, batch_size=512, epochs=10, verbose=1,validation_data=(test_images, test_labels))
score = model.evaluate(test_images, test_labels, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.7824 - loss: 0.6995 - val_accuracy: 0.9647 - val_loss: 0.1208
# Epoch 2/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9706 - loss: 0.0972 - val_accuracy: 0.9437 - val_loss: 0.1842
# Epoch 3/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9767 - loss: 0.0784 - val_accuracy: 0.9791 - val_loss: 0.0741
# Epoch 4/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9791 - loss: 0.0775 - val_accuracy: 0.9774 - val_loss: 0.0848
# Epoch 5/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9805 - loss: 0.0887 - val_accuracy: 0.9657 - val_loss: 0.2329
# Epoch 6/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9811 - loss: 0.1138 - val_accuracy: 0.9757 - val_loss: 0.1713
# Epoch 7/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9762 - loss: 0.2030 - val_accuracy: 0.9766 - val_loss: 0.2834
# Epoch 8/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9742 - loss: 0.3887 - val_accuracy: 0.9783 - val_loss: 0.5215
# Epoch 9/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9773 - loss: 0.5101 - val_accuracy: 0.9624 - val_loss: 1.2567
# Epoch 10/10
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9739 - loss: 0.9206 - val_accuracy: 0.9403 - val_loss: 3.2337
# Test loss: 3.233747959136963
# Test accuracy: 0.9402999877929688

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_labels = tf.keras.utils.to_categorical (train_labels)
test_labels = tf.keras.utils.to_categorical (test_labels)
train_images, test_images = train_images / 255.0, test_images / 255.0


input = layers.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 1, activation='relu', padding='same')(input)
ident = layers.Conv2D(64, 1, padding="same")(x)
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.add([ident,x])
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.add([ident,x])
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.add([ident,x])
x = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = layers.add([ident,x])
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.5)(x)
x = layers.Dense(10, activation='softmax')(x)
model = tf.keras.models.Model(inputs=input, outputs=x)

model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])
model.fit(train_images, train_labels, batch_size=512, epochs=10, verbose=1, validation_data=(test_images, test_labels))

score = model.evaluate(test_images, test_labels, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 11s 103ms/step - accuracy: 0.1216 - loss: 21.1631 - val_accuracy: 0.3118 - val_loss: 7.1381
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - accuracy: 0.1989 - loss: 27.6295 - val_accuracy: 0.3733 - val_loss: 8.0430
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.2503 - loss: 18.0371 - val_accuracy: 0.4261 - val_loss: 3.3368
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.2802 - loss: 6.5348 - val_accuracy: 0.4326 - val_loss: 1.9510
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 101ms/step - accuracy: 0.3172 - loss: 2.6004 - val_accuracy: 0.4405 - val_loss: 1.5636
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.3605 - loss: 1.8047 - val_accuracy: 0.4361 - val_loss: 1.5223
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.3651 - loss: 1.7401 - val_accuracy: 0.4438 - val_loss: 1.5161
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.3664 - loss: 1.7910 - val_accuracy: 0.4526 - val_loss: 1.5239
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.3820 - loss: 1.7648 - val_accuracy: 0.4302 - val_loss: 1.6313
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - accuracy: 0.3930 - loss: 1.7896 - val_accuracy: 0.4295 - val_loss: 1.5879
# Test loss: 1.5879199504852295
# Test accuracy: 0.429500013589859

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D

(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()
train_labels = tf.keras.utils.to_categorical (train_labels)
test_labels = tf.keras.utils.to_categorical (test_labels)
train_images, test_images = train_images / 255.0, test_images / 255.0


x = layers.Conv2D(64, 1, activation='relu', padding='same')(input)
for i in range (5):
    ident = x
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.add([ident,x])
    
flatten = layers.Flatten()(x)
dense = layers.Dense(10, activation="softmax")(flatten)
model = tf.keras.models.Model(inputs=input, outputs=dense)

model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(), metrics=['accuracy'])
model.fit(train_images, train_labels, batch_size=512, epochs=10, verbose=1, validation_data=(test_images, test_labels))

score = model.evaluate(test_images, test_labels, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 24s 228ms/step - accuracy: 0.2286 - loss: 3.0934 - val_accuracy: 0.4052 - val_loss: 1.6836
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 226ms/step - accuracy: 0.4343 - loss: 1.6160 - val_accuracy: 0.4814 - val_loss: 1.4505
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 227ms/step - accuracy: 0.4953 - loss: 1.4126 - val_accuracy: 0.5286 - val_loss: 1.3228
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.5525 - loss: 1.2766 - val_accuracy: 0.5574 - val_loss: 1.2427
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.5885 - loss: 1.1653 - val_accuracy: 0.5754 - val_loss: 1.1897
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 230ms/step - accuracy: 0.6223 - loss: 1.0738 - val_accuracy: 0.5907 - val_loss: 1.1380
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - accuracy: 0.6525 - loss: 0.9818 - val_accuracy: 0.6358 - val_loss: 1.0429
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.6875 - loss: 0.8951 - val_accuracy: 0.6430 - val_loss: 1.0198
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - accuracy: 0.7199 - loss: 0.8079 - val_accuracy: 0.6437 - val_loss: 1.0476
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - accuracy: 0.7427 - loss: 0.7511 - val_accuracy: 0.6585 - val_loss: 1.0096
# Test loss: 1.0096275806427002
# Test accuracy: 0.6585000157356262

# %%
import tensorflow as tf
from tensorflow.keras import layers
input = layers.Input(shape=(32, 32, 3))
x = layers.Conv2D(64, 1, activation='relu', padding='same')(input)
for i in range (5):
    ident = x
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.Conv2D(64, 3, activation='relu', padding='same')(x)
    x = layers.add([ident,x])
flatten = layers.Flatten()(x)
dense = layers.Dense(10, activation="softmax")(flatten)
model = tf.keras.models.Model(inputs=input, outputs=dense)

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

model.compile(optimizer=tf.keras.optimizers.RMSprop(1e-3),
loss='categorical_crossentropy',
metrics=['acc'])
model.fit(x_train, y_train,
batch_size=64,
epochs=1,
validation_split=0.2)

model.fit(x_train, y_train, batch_size=512, epochs=10, verbose=1, validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - acc: 0.3227 - loss: 2.7805 - val_acc: 0.5413 - val_loss: 1.2933
# Epoch 1/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 225ms/step - acc: 0.5715 - loss: 1.2196 - val_acc: 0.5796 - val_loss: 1.1831
# Epoch 2/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 225ms/step - acc: 0.6080 - loss: 1.1150 - val_acc: 0.6180 - val_loss: 1.0727
# Epoch 3/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 224ms/step - acc: 0.6419 - loss: 1.0263 - val_acc: 0.5770 - val_loss: 1.2115
# Epoch 4/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 225ms/step - acc: 0.6725 - loss: 0.9438 - val_acc: 0.6219 - val_loss: 1.0785
# Epoch 5/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 227ms/step - acc: 0.6985 - loss: 0.8664 - val_acc: 0.6282 - val_loss: 1.0863
# Epoch 6/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - acc: 0.7223 - loss: 0.8053 - val_acc: 0.6401 - val_loss: 1.0482
# Epoch 7/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 22s 229ms/step - acc: 0.7462 - loss: 0.7298 - val_acc: 0.6566 - val_loss: 1.0086
# Epoch 8/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - acc: 0.7701 - loss: 0.6635 - val_acc: 0.6336 - val_loss: 1.0901
# Epoch 9/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 237ms/step - acc: 0.7917 - loss: 0.5985 - val_acc: 0.6199 - val_loss: 1.2058
# Epoch 10/10
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 23s 234ms/step - acc: 0.8106 - loss: 0.5447 - val_acc: 0.6455 - val_loss: 1.1222
# Test loss: 1.1221758127212524
# Test accuracy: 0.6455000042915344
